# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mohan N**
# <br>I desire to be a Data Scientist

# %% [markdown]
# *I am interested in Data Science because I love how the industry relies on data to make certain decisions, to solve complex problems, to grow, and to discover*

# %% [markdown]
# ### This code will return the square of the passed number

# %%
def square(num):
    return num*num

ans = square(25)
print('Result: ',ans)
# Out:
# Result:  625

# %% [markdown]
# `Cell 6`
#
# ---
#
# ~~The world is flat.~~
